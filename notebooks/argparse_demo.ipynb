# %%
"""
NOTE:
- This is a very basic script to test if our dependencies are working correctly. 
"""

import argparse
import glob
import os
import re
import numpy as np
from pathlib import Path
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import tifffile as tiff

# Raster backends
try:
    import rasterio
    RASTER_BACKEND = "rasterio"
except Exception:
    rasterio = None
    try:
        import tifffile as tiff
        RASTER_BACKEND = "tifffile"
    except Exception:
        tiff = None
        RASTER_BACKEND = None

# %%
print("tifffile:", tiff.__version__)
print("numpy:", np.__version__)
print("torch:", torch.__version__, "CUDA build:", torch.version.cuda, "CUDA avail:", torch.cuda.is_available(), "CUDA device count:", torch.cuda.device_count())
print("raterio:", rasterio.__version__)
if torch.cuda.is_available(): 
    print("GPU0", torch.cuda.get_device_name(0))
# Out:
# tifffile: 2025.10.16
# numpy: 2.3.4
# torch: 2.10.0.dev20251107+cu128 CUDA build: 12.8 CUDA avail: True CUDA device count: 1
# raterio: 1.4.3
# GPU0 NVIDIA L40S

# %%
# Out:
# LOL
